# %%
import pandas as pd

# %%
prt = pd.read_csv('data/prt_monthly_ridership.csv')

# %%
prt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26483 entries, 0 to 26482
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Route            26483 non-null  str
#  1   Route_Full_Name  26281 non-null  str
#  2   Current_Garage   26289 non-null  str
#  3   Mode             26483 non-null  str
#  4   Month_Start      26483 non-null  str
#  5   Date_Key         26483 non-null  int64
#  6   Day_Type         26483 non-null  str
#  7   Avg_Riders       26483 non-null  float64
#  8   Day_Count        26483 non-null  int64
# dtypes: float64(1), int64(2), str(6)
# memory usage: 1.8 MB

# %%
prt.head(10)
# Out:
#   Route    Route_Full_Name Current_Garage Mode Month_Start  Date_Key Day_Type  \
# 0     1  1 - FREEPORT ROAD           Ross  Bus    4/1/2026    202604     SAT.
# 1    11      11 - FINEVIEW           Ross  Bus    4/1/2026    202604     SAT.
# 2    12      12 - MCKNIGHT           Ross  Bus    4/1/2026    202604     SAT.
# 3    13      13 - BELLEVUE           Ross  Bus    4/1/2026    202604     SAT.
# 4    14   14 - OHIO VALLEY           Ross  Bus    4/1/2026    202604     SAT.
# 5    15       15 - CHARLES           Ross  Bus    4/1/2026    202604     SAT.
# 6    16      16 - BRIGHTON           Ross  Bus    4/1/2026    202604     SAT.
# 7    17     17 - SHADELAND           Ross  Bus    4/1/2026    202604     SAT.
# 8     2    2 - MOUNT ROYAL           Ross  Bus    4/1/2026    202604     SAT.
# 9    20       20 - KENNEDY        Collier  Bus    4/1/2026    202604     SAT.
#
#    Avg_Riders  Day_Count
# 0     1339.50          4
# 1      191.00          4
# 2     1081.00          4
# 3     1310.25          4
# 4      348.75          4
# 5      600.50          4
# 6     1414.25          4
# 7      388.50          4
# 8      180.25          4
# 9      280.50          4

# %%
prt.describe(include='all')
# Out:
#         Route    Route_Full_Name Current_Garage   Mode Month_Start  \
# count   26483              26281          26289  26483       26483
# unique    111                103              6      3         112
# top         1  1 - FREEPORT ROAD   East Liberty    Bus    4/1/2026
# freq      336                336           7579  25118         250
# mean      NaN                NaN            NaN    NaN         NaN
# std       NaN                NaN            NaN    NaN         NaN
# min       NaN                NaN            NaN    NaN         NaN
# 25%       NaN                NaN            NaN    NaN         NaN
# 50%       NaN                NaN            NaN    NaN         NaN
# 75%       NaN                NaN            NaN    NaN         NaN
# max       NaN                NaN            NaN    NaN         NaN
#
#              Date_Key Day_Type    Avg_Riders     Day_Count
# count    26483.000000    26483  26483.000000  26483.000000
# unique            NaN        3           NaN           NaN
# top               NaN  WEEKDAY           NaN           NaN
# freq              NaN    11151           NaN           NaN
# mean    202132.174149      NaN   1145.557665     11.604916
# std        269.007458      NaN   1321.945759      8.307031
# min     201701.000000      NaN     -1.954545      3.000000
# 25%     201906.000000      NaN    327.925000      4.000000
# 50%     202110.000000      NaN    709.500000      5.000000
# 75%     202401.000000      NaN   1449.647727     21.000000
# max     202604.000000      NaN  11510.250000     23.000000

# %%
for c in ['Route','Route_Full_Name','Current_Garage','Mode','Month_Start','Day_Type']:
    print(prt[c].value_counts(dropna=False).head(5))
# Out:
# Route
# 1     336
# 11    336
# 12    336
# 13    336
# 14    336
# Name: count, dtype: int64
# Route_Full_Name
# 1 - FREEPORT ROAD    336
# 11 - FINEVIEW        336
# 12 - MCKNIGHT        336
# 13 - BELLEVUE        336
# 14 - OHIO VALLEY     336
# Name: count, dtype: int64
# Current_Garage
# East Liberty           7579
# West Mifflin           6404
# Ross                   5697
# Collier                5254
# South Hills Village    1042
# Name: count, dtype: int64
# Mode
# Bus        25118
# Rail        1052
# Incline      313
# Name: count, dtype: int64
# Month_Start
# 4/1/2026     250
# 7/1/2024     247
# 6/1/2024     247
# 10/1/2025    245
# 7/1/2025     245
# Name: count, dtype: int64
# Day_Type
# WEEKDAY    11151
# SAT.        7837
# SUN.        7495
# Name: count, dtype: int64
